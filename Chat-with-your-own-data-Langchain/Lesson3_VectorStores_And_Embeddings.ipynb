# %% [markdown]
# # Vectorstores and Embeddings

# %%
import os
import openai
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
from langchain.document_loaders import PyPDFLoader

loaders = [
    # Duplicate documents on purpose - messy data
    PyPDFLoader("docs/MachineLearning-Lecture01.pdf"),
    PyPDFLoader("docs/MachineLearning-Lecture01.pdf"),
    PyPDFLoader("docs/MachineLearning-Lecture02.pdf"),
    PyPDFLoader("docs/MachineLearning-Lecture03.pdf")
]
docs = []
for loader in loaders:
    docs.extend(loader.load())

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_spilliter = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=150)

# %%
splits = text_spilliter.split_documents(docs)

# %%
len(splits)
# Out:
# 209

# %% [markdown]
# ## Embeddings

# %%
from langchain_openai.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %%
sentence1 = "i like |dogs"
sentence2 = "i like canines"
sentence3 = "the weather is ugly outside"

# %%
embedding1 = embeddings.embed_query(sentence1)
embedding2 = embeddings.embed_query(sentence2)
embedding3 = embeddings.embed_query(sentence3)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 embedding1 = embeddings.embed_query(sentence1)
#       2 embedding2 = embeddings.embed_query(sentence2)
#       3 embedding3 = embeddings.embed_query(sentence3)
#
# File ~/projects/ES/OpenAI-labs/34-langchain-chat-with-your-own-data/myenv/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:620, in OpenAIEmbeddings.embed_query(self, text)
#     611 def embed_query(self, text: str) -> list[float]:
#     612     """Call out to OpenAI's embedding endpoint for embedding query text.
#     613
#     614     Args:
#    (...)    618         Embedding for the text.
#     619     """
# --> 620     return self.embed_documents([text])[0]
#
# File ~/projects/ES/OpenAI-labs/34-langchain-chat-with-your-own-data/myenv/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:575, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     572 # NOTE: to keep things simple, we assume the list may contain texts longer
#     573 #       than the maximum context and use length-safe embedding function.
#     574 engine = cast(str, self.deployment)
# --> 575 return self._get_len_safe_embeddings(
#     576     texts, engine=engine, chunk_size=chunk_size
#     577 )
#
# File ~/projects/ES/OpenAI-labs/34-langchain-chat-with-your-own-data/myenv/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:471, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     469 batched_embeddings: list[list[float]] = []
#     470 for i in _iter:
# --> 471     response = self.client.create(
#     472         input=tokens[i : i + _chunk_size], **self._invocation_params
#     473     )
#     474     if not isinstance(response, dict):
#     475         response = response.model_dump()
#
# File ~/projects/ES/OpenAI-labs/34-langchain-chat-with-your-own-data/myenv/lib/python3.12/site-packages/openai/resources/embeddings.py:128, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     122             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     123                 base64.b64decode(data), dtype="float32"
#     124             ).tolist()
#     126     return obj
# --> 128 return self._post(
#     129     "/embeddings",
#     130     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     131     options=make_request_options(
#     132         extra_headers=extra_headers,
#     133         extra_query=extra_query,
#     134         extra_body=extra_body,
#     135         timeout=timeout,
#     136         post_parser=parser,
#     137     ),
#     138     cast_to=CreateEmbeddingResponse,
#     139 )
#
# File ~/projects/ES/OpenAI-labs/34-langchain-chat-with-your-own-data/myenv/lib/python3.12/site-packages/openai/_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)   1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projects/ES/OpenAI-labs/34-langchain-chat-with-your-own-data/myenv/lib/python3.12/site-packages/openai/_base_client.py:1034, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1031             err.response.read()
#    1033         log.debug("Re-raising status error")
# -> 1034         raise self._make_status_error_from_response(err.response) from None
#    1036     break
#    1038 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-jedT2***************************************ZSKC. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
import numpy as np

# %%
np.dot(embedding1, embedding2)

# %%
np.dot(embedding1, embedding3)

# %%
np.dot(embedding2, embedding3)

# %% [markdown]
# ## Vectorstores

# %%
from langchain.vectorstores import Chroma

# %%
persist_directory = 'docs/chroma/'

# %%
vectordb = Chroma.from_documents(documents=splits,
                                 embedding=embeddings,
                                 persist_directory=persist_directory)

# %%
print(vectordb._collection.count())

# %% [markdown]
# ## Similarity search

# %%
question = "is there an email i can ask for help"

# %%
docs = vectordb.similarity_search(question, k=3)

# %%
len(docs)

# %%
docs[0].page_content

# %% [markdown]
# ## Failure modes

# %%
question = "what did they say about matlab?"

# %%
docs = vectordb.similarity_search(question, k=5)

# %%
docs[0]

# %%
docs[1]

# %%
question = "what did they say about regression in the third lecture?"

# %%
docs = vectordb.similarity_search(question, k=5)

# %%
for doc in docs:
    print(doc.metadata)

# %%
print(docs[4].page_content)
