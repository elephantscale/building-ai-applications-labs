# %%
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
openai.api_key  = os.getenv('OPENAI_API_KEY')
MODEL=os.getenv('LLM_MODEL')

# %%
# For OpenAI after 1.0.0
client = openai.OpenAI()

def get_completion(prompt, model=MODEL):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %% [markdown]
# ## Generate a marketing product description from a product fact sheet

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Elevate your workspace with our exquisite mid-century inspired office chair, a perfect blend of style and functionality. Part of a stunning collection of office furniture, this chair is designed to complement any setting, whether at home or in a business environment. With a variety of shell colors and base finishes, you can customize it to match your unique aesthetic.
#
# Choose between the sleek plastic back and front upholstery (SWC-100) or indulge in the luxurious full upholstery (SWC-110), available in 10 fabric and 6 leather options. The base is offered in four sophisticated finishes: stainless steel, matte black, gloss white, or chrome, ensuring a perfect match for your decor.
#
# Designed for comfort and versatility, this chair features a 5-wheel plastic coated aluminum base and a pneumatic adjuster for effortless height adjustments. Its dimensions are thoughtfully crafted to provide optimal support: 53 cm (20.87”) in width, 51 cm (20.08”) in depth, and 80 cm (31.50”) in height, with a seat height of 44 cm (17.32”) and a seat depth of 41 cm (16.14”).
#
# Tailor your seating experience with options for soft or hard-floor casters, two seat foam densities (medium or high), and the choice of armless design or 8-position PU armrests. The chair's shell is made from durable cast aluminum with a modified nylon PA6/PA66 coating, ensuring longevity and style.
#
# Crafted in Italy, this chair is not only a testament to fine craftsmanship but also qualified for contract use, making it a reliable choice for any professional setting. Experience the perfect fusion of design and comfort with our mid-century inspired office chair.

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.

# %%
len(response)
# Out:
# 1636

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# This mid-century inspired office chair features a durable cast aluminum shell with a modified nylon PA6/PA66 coating. It offers a 5-wheel plastic-coated aluminum base and HD36 foam seating. Available in various finishes and upholstery options, it suits both home and business environments. Made in Italy.

# %% [markdown]
# Try to say "Use at most 3 sentences" or "Use at most 280 characters"

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# - Ask it to focus on the aspects that are relevant to the intended audience.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# This mid-century inspired office chair features a cast aluminum shell with a modified nylon PA6/PA66 coating and a 5-wheel plastic-coated aluminum base. Available in various shell colors and base finishes, it offers options for upholstery, armrests, and seat foam densities. Made in Italy, it suits both home and business environments.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# This mid-century inspired office chair features a durable cast aluminum shell with a modified nylon PA6/PA66 coating and a 5-wheel plastic-coated aluminum base. Available in various finishes and upholstery options, it offers customizable comfort with two seat foam densities. Ideal for home or business use. Product IDs: SWC-100, SWC-110.

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# ```html
# <div>
#     Discover the perfect blend of style and functionality with our mid-century inspired office chair, designed to complement any office setting, whether at home or in a business environment. This chair is part of a comprehensive collection that includes filing cabinets, desks, bookcases, and meeting tables, all crafted to meet the highest standards of quality and design.
#
#     Constructed with a 5-wheel plastic coated aluminum base, this chair offers both durability and mobility. The pneumatic chair adjust feature allows for easy height adjustments, ensuring comfort for users of all sizes. The chair is available in two upholstery options: a plastic back and front upholstery (SWC-100) or full upholstery (SWC-110), with a selection of 10 fabric and 6 leather finishes to suit any decor.
#
#     The base of the chair can be finished in stainless steel, matte black, gloss white, or chrome, providing a range of aesthetic options. Additionally, the chair can be customized with or without armrests, and offers soft or hard-floor caster options to accommodate different flooring types. Choose between medium or high-density seat foam to tailor the comfort level to your preference.
#
#     The shell of the chair is made from cast aluminum with a modified nylon PA6/PA66 coating, ensuring a robust and long-lasting structure. The seat is crafted from HD36 foam, providing excellent support and comfort.
#
#     This chair is not only a stylish addition to any office but is also qualified for contract use, making it a versatile choice for various settings.
#
#     Product IDs: SWC-100, SWC-110
# </div>
#
# <table>
#     <caption>Product Dimensions</caption>
#     <tr>
#         <th>Dimension</th>
#         <th>Measurement (inches)</th>
#     </tr>
#     <tr>
#         <td>Width</td>
#         <td>20.87”</td>
#     </tr>
#     <tr>
#         <td>Depth</td>
#         <td>20.08”</td>
#     </tr>
#     <tr>
#         <td>Height</td>
#         <td>31.50”</td>
#     </tr>
#     <tr>
#         <td>Seat Height</td>
#         <td>17.32”</td>
#     </tr>
#     <tr>
#         <td>Seat Depth</td>
#         <td>16.14”</td>
#     </tr>
# </table>
# ```

# %% [markdown]
# ## Load Python libraries to view HTML

# %%
from IPython.display import display, HTML

# %%
display(HTML(response))
# Out:
# ```html
# <div>
#     Discover the perfect blend of style and functionality with our mid-century inspired office chair, designed to complement any office setting, whether at home or in a business environment. This chair is part of a comprehensive collection that includes filing cabinets, desks, bookcases, and meeting tables, all crafted to meet the highest standards of quality and design.
#
#     Constructed with a 5-wheel plastic coated aluminum base, this chair offers both durability and mobility. The pneumatic chair adjust feature allows for easy height adjustments, ensuring comfort for users of all sizes. The chair is available in two upholstery options: a plastic back and front upholstery (SWC-100) or full upholstery (SWC-110), with a selection of 10 fabric and 6 leather finishes to suit any decor.
#
#     The base of the chair can be finished in stainless steel, matte black, gloss white, or chrome, providing a range of aesthetic options. Additionally, the chair can be customized with or without armrests, and offers soft or hard-floor caster options to accommodate different flooring types. Choose between medium or high-density seat foam to tailor the comfort level to your preference.
#
#     The shell of the chair is made from cast aluminum with a modified nylon PA6/PA66 coating, ensuring a robust and long-lasting structure. The seat is crafted from HD36 foam, providing excellent support and comfort.
#
#     This chair is not only a stylish addition to any office but is also qualified for contract use, making it a versatile choice for various settings.
#
#     Product IDs: SWC-100, SWC-110
# </div>
#
# <table>
#     <caption>Product Dimensions</caption>
#     <tr>
#         <th>Dimension</th>
#         <th>Measurement (inches)</th>
#     </tr>
#     <tr>
#         <td>Width</td>
#         <td>20.87”</td>
#     </tr>
#     <tr>
#         <td>Depth</td>
#         <td>20.08”</td>
#     </tr>
#     <tr>
#         <td>Height</td>
#         <td>31.50”</td>
#     </tr>
#     <tr>
#         <td>Seat Height</td>
#         <td>17.32”</td>
#     </tr>
#     <tr>
#         <td>Seat Depth</td>
#         <td>16.14”</td>
#     </tr>
# </table>
# ```

# %% [markdown]
# ## Try experimenting on your own!
